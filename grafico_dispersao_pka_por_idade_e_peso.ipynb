# %% [markdown]
# <a href="https://colab.research.google.com/github/GeorgiaAAAl/GeorgiaAAAl/blob/main/grafico_dispersao_pka_por_idade_e_peso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_excel('/content/drive/MyDrive/georgia/GEORGIA.xlsx')
display(df)
# Out:
#      Data proc    G1 Protocol  Prontuário        Age CATEGORIA  \
# 0   2023-07-07        CARDIAC    17170622   0.070000         A
# 1   2019-05-07         THORAX    15788953   0.083333         A
# 2   2021-03-28         THORAX    16336737   0.083333         A
# 3   2020-03-26  ORTHOPAEDICS     16088098   0.087600         A
# 4   2022-07-04         THORAX    16792020   0.098600         A
# ..         ...            ...         ...        ...       ...
# 827 2018-06-15         THORAX    14302897  17.000000         E
# 828 2020-10-15         THORAX    16147548  18.000000         E
# 829 2020-01-07    VASCULAR HQ     9020157  18.000000         E
# 830 2019-06-11         THORAX     8684706  18.000000         E
# 831 2019-03-29         THORAX    14302897  18.000000         E
#
#      PKA DAP total (Gy.cm^2)
# 0                     0.3400
# 1                     0.0323
# 2                     0.0146
# 3                     0.0317
# 4                     0.0423
# ...

# %%
categoria_cont = df['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E'])
display(categoria_cont)
# Out:
# CATEGORIA
# A    221
# B    379
# C    107
# D     87
# E     38
# Name: count, dtype: int64

# %%
categoriasestat = df.groupby('CATEGORIA')['PKA DAP total (Gy.cm^2)'].describe()
categorias_dados = categoriasestat[['min', '50%', '75%', 'max','std']]
display(categorias_dados)
# Out:
#                 min     50%     75%    max       std
# CATEGORIA
# A          0.001300  0.0669  0.2040  16.70  1.300828
# B          0.000219  0.0880  0.3260   9.34  1.172407
# C          0.000598  0.1700  0.4690  17.80  2.023097
# D          0.004640  0.3120  1.0650   8.37  2.015320
# E          0.013100  0.2790  1.0375  19.90  3.700750

# %%
faixa_ano = {
    'A': '< 1',
    'B': '1 < 5',
    'C': '5 < 10',
    'D': '10 < 15',
    'E': '  ≥ 15 '
}

# %%
df2 = pd.read_excel('/content/drive/MyDrive/georgia/georgia.xlsx')
display(df)
# Out:
#      Data proc G1 Protocol Prontuário  Mass (kg) CATEGORIA  \
# 0   2018-10-15      THORAX   14291066      2.195         A
# 1   2020-12-08      THORAX   16274896      2.215         A
# 2   2019-05-07      THORAX   15788953      2.250         A
# 3   2022-10-21  VASCLAR HQ   16902561      2.315         A
# 4   2023-01-11      THORAX   16954091      2.330         A
# ..         ...         ...        ...        ...       ...
# 811 2017-11-17      THORAX   11958014     95.700         F
# 812 2018-04-16      THORAX   14231666     96.000         F
# 813 2021-03-22      THORAX   16278137     98.000         F
# 814 2021-03-29      THORAX   16278137     98.000         F
# 815 2019-05-08      THORAX   11834975    108.500         F
#
#      PKA DAP total (Gy.cm^2)
# 0                     0.0307
# 1                     0.0200
# 2                     0.0323
# 3                     0.0422
# 4                     0.0113
# ..                       ...
# 811                   1.1700
# ...

# %%
categoria_cont = df['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E'])
display(categoria_cont)
# Out:
# CATEGORIA
# A     80
# B    439
# C    153
# D     77
# E     56
# Name: count, dtype: int64

# %%
categoriasestat = df.groupby('CATEGORIA')['PKA DAP total (Gy.cm^2)'].describe()
categorias_dados = categoriasestat[['min', '50%', '75%', 'max','std']]
display(categorias_dados)
# Out:
#                 min      50%     75%    max       std
# CATEGORIA
# A          0.001300  0.04355  0.1765   2.13  0.343025
# B          0.000219  0.08040  0.2780  16.70  1.240332
# C          0.002330  0.14300  0.4080   9.34  1.326233
# D          0.004640  0.18900  0.9040   8.65  1.974021
# E          0.006850  0.30700  1.0130  19.90  3.682342
# F          0.201000  1.04000  3.9000  12.10  3.645836

# %%
faixa_kg = {
    'A': '< 5 kg',
    'B': '5 < 15 kg',
    'C': '15 < 30 kg',
    'D': '30 < 50 kg',
    'E': '50 < 80 kg',
    'F': '  80 kg < '
}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carregar os arquivos CSV
# Substitua os caminhos dos arquivos pelos que estão no seu Google Drive (pode usar caminho local ou o link compartilhado)
file_id_pka_idade = ('/content/drive/MyDrive/georgia/GEORGIA.xlsx')
file_id_pka_peso = ('/content/drive/MyDrive/georgia/GEORGIA.xlsx')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os arquivos Excel
file_id_pka_idade = '/content/drive/MyDrive/georgia/GEORGIA.xlsx'
file_id_pka_peso = '/content/drive/MyDrive/georgia/georgia.xlsx'



#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')


from google.colab import drive
drive.mount('/content/drive')

df_idade = pd.read_excel('/content/drive/MyDrive/georgia/GEORGIA.xlsx')
display(df)

#df_peso = pd.read_excel ('/content/drive/MyDrive/georgia/georgia.xlsx')

categoria_cont = df_idade['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E'])
display(categoria_cont)


categoriasestat = df.groupby('CATEGORIA')['PKA DAP total (Gy.cm^2)'].describe()
categorias_dados = categoriasestat[['min', '50%', '75%', 'max','std']]
display(categorias_dados)

# Carregar os arquivos Excel
#file_id_idade = '/content/drive/MyDrive/georgia/GEORGIA.xlsx'
#file_id_peso = '/content/drive/MyDrive/georgia/georgia.xlsx'
# Dados fornecidos (como exemplo com base nas tabelas)
dados_idade = {
    'df': df_idade,
    'categoria_cont': categoria_cont,
    'categorias_dados': categorias_dados
}

# Dados fornecidos (como exemplo com base nas tabelas)
#dados_peso = {
    #'df': df_peso,
    #'categoria_cont': categoria_cont,
    #'categorias_dados': categorias_dados
#}



# Criando DataFrames
df_idade = dados_idade['df']  # Access the 'df' key from dados_idade
#df_peso = dados_peso['df']   # Access the 'df' key from dados_peso


# Plotando o gráfico de dispersão
plt.figure(figsize=(12, 8))

# Dispersão para Faixa de Idade
plt.scatter(df_idade['PKA DAP total (Gy.cm^2)'], df_idade['CATEGORIA'], color='blue', label='Faixa de Idade', s=100)

# Dispersão para Faixa de Peso
#plt.scatter(df_peso['PKA DAP total (Gy.cm^2)'], df_peso['CATEGORIA'], color='red', label='Faixa de Peso', s=100)

# Títulos e rótulos
plt.title('Gráfico de Dispersão: Q2 PKA vs Faixa de Idade e Faixa de Peso')
plt.xlabel('Q2 PKA (Gycm²)')
plt.ylabel('Faixa de Idade / Faixa de Peso')

# Legenda
plt.legend()

# Exibir o gráfico
plt.grid(True)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Data proc G1 Protocol Prontuário  Mass (kg) CATEGORIA  \
# 0   2018-10-15      THORAX   14291066      2.195         A
# 1   2020-12-08      THORAX   16274896      2.215         A
# 2   2019-05-07      THORAX   15788953      2.250         A
# 3   2022-10-21  VASCLAR HQ   16902561      2.315         A
# 4   2023-01-11      THORAX   16954091      2.330         A
# ..         ...         ...        ...        ...       ...
# 811 2017-11-17      THORAX   11958014     95.700         F
# 812 2018-04-16      THORAX   14231666     96.000         F
# 813 2021-03-22      THORAX   16278137     98.000         F
# 814 2021-03-29      THORAX   16278137     98.000         F
# 815 2019-05-08      THORAX   11834975    108.500         F
#
#      PKA DAP total (Gy.cm^2)
# 0                     0.0307
# 1                     0.0200
# 2                     0.0323
# ...

# %%
# @title Mass (kg) vs PKA DAP total (Gy.cm^2)

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Mass (kg)', y='PKA DAP total (Gy.cm^2)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: idade (anos ) vs Pka total

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the Excel file
df_idade = pd.read_excel('/content/drive/MyDrive/georgia/GEORGIA.xlsx')

# Assuming 'IDADE' column exists in your dataframe
# If not, replace 'IDADE' with the actual column name representing age
if 'IDADE' not in df_idade.columns:
    print("Error: 'IDADE' column not found in the dataframe. Please replace 'IDADE' with the correct column name.")
else:
    # Calculate descriptive statistics for PKA grouped by age categories
    categoriasestat_idade = df_idade.groupby('CATEGORIA')['PKA DAP total (Gy.cm^2)'].describe()
    categorias_dados_idade = categoriasestat_idade[['min', '50%', '75%', 'max', 'std']]

    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.errorbar(df_idade['CATEGORIA'], categorias_dados_idade['50%'], yerr=categorias_dados_idade['std'], fmt='o-', capsize=5)
    plt.xlabel('Categoria de Idade')
    plt.ylabel('PKA DAP total (Gy.cm^2)')
    plt.title('PKA vs. Categoria de Idade')
    plt.grid(True)
    plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error: 'IDADE' column not found in the dataframe. Please replace 'IDADE' with the correct column name.

# %%
idade (anos ) vs PKA DAP total (Gy.cm^2)
# Out:
#   File "<ipython-input-58-a1d3f7b3eab8>", line 1
#     idade (anos ) vs PKA DAP total (Gy.cm^2)
#                   ^
# SyntaxError: invalid syntax

# %%
# @title Mass (kg) vs PKA DAP total (Gy.cm^2)

#from matplotlib import pyplot as plt
#df.plot(kind='scatter', x='Mass (kg)', y='PKA total (Gy.cm^2)', s=32, alpha=.8)
#plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/georgia/georgia.xlsx')
display(df)
# Out:
#      Data proc G1 Protocol Prontuário  Peso (kg) CATEGORIA  PKA  total (Gycm²)
# 0   2018-10-15      THORAX   14291066      2.195         A              0.0307
# 1   2020-12-08      THORAX   16274896      2.215         A              0.0200
# 2   2019-05-07      THORAX   15788953      2.250         A              0.0323
# 3   2022-10-21  VASCLAR HQ   16902561      2.315         A              0.0422
# 4   2023-01-11      THORAX   16954091      2.330         A              0.0113
# ..         ...         ...        ...        ...       ...                 ...
# 811 2017-11-17      THORAX   11958014     95.700         F              1.1700
# 812 2018-04-16      THORAX   14231666     96.000         F              0.5590
# 813 2021-03-22      THORAX   16278137     98.000         F              3.5300
# 814 2021-03-29      THORAX   16278137     98.000         F              0.2010
# 815 2019-05-08      THORAX   11834975    108.500         F              6.1600
#
# [816 rows x 6 columns]

# %%
categoria_cont = df['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E', 'F'])
display(categoria_cont)
# Out:
# CATEGORIA
# A     80
# B    439
# C    153
# D     77
# E     56
# F     11
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_excel('/content/drive/MyDrive/georgia/georgia.xlsx')
display(df)

categoria_cont = df['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E', 'F'])
display(categoria_cont)

# Imprimindo as colunas do DataFrame para verificar o nome correto
print(df.columns)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Data proc G1 Protocol Prontuário  Peso (kg) CATEGORIA  \
# 0   2018-10-15      THORAX   14291066      2.195         A
# 1   2020-12-08      THORAX   16274896      2.215         A
# 2   2019-05-07      THORAX   15788953      2.250         A
# 3   2022-10-21  VASCLAR HQ   16902561      2.315         A
# 4   2023-01-11      THORAX   16954091      2.330         A
# ..         ...         ...        ...        ...       ...
# 811 2017-11-17      THORAX   11958014     95.700         F
# 812 2018-04-16      THORAX   14231666     96.000         F
# 813 2021-03-22      THORAX   16278137     98.000         F
# 814 2021-03-29      THORAX   16278137     98.000         F
# 815 2019-05-08      THORAX   11834975    108.500         F
#
#      PKA DAP total (Gy.cm^2)
# 0                     0.0307
# 1                     0.0200
# 2                     0.0323
# ...

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Peso (kg)', y='PKA DAP total (Gy.cm^2)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt

# Criar o gráfico de dispersão
df.plot(kind='scatter', x='Peso (kg)', y='PKA DAP total (Gy.cm^2)', s=32, alpha=.8)

# Configurar para remover os eixos superiores e à direita
plt.gca().spines[['top', 'right']].set_visible(False)

# Adicionar os valores de PKA correspondentes às faixas de peso como texto
plt.text(x=2.5, y=0.04355, s='0.04355', color='black', ha='center', va='bottom')  # Valor para <5 kg
plt.text(x=10, y=0.0804, s='0.0804', color='black', ha='center', va='bottom')     # Valor para 5 a <15 kg
plt.text(x=22.5, y=0.1430, s='0.1430', color='black', ha='center', va='bottom')   # Valor para 15 a <30 kg
plt.text(x=40, y=0.1890, s='0.1890', color='black', ha='center', va='bottom')     # Valor para 30 a <50 kg
plt.text(x=65, y=0.370, s='0.370', color='black', ha='center', va='bottom')       # Valor para 50 a <80 kg
plt.text(x=90, y=1.04, s='1.04', color='black', ha='center', va='bottom')         # Valor para >80 kg corrigido

# Mostrar o gráfico
plt.show()

# %%
categoriasestat = df.groupby('CATEGORIA')['PKA DAP total (Gy.cm^2)'].describe()
categorias_dados = categoriasestat[['min', '50%', '75%', 'max','std']]
display(categorias_dados)
# Out:
#                 min      50%     75%    max       std
# CATEGORIA
# A          0.001300  0.04355  0.1765   2.13  0.343025
# B          0.000219  0.08040  0.2780  16.70  1.240332
# C          0.002330  0.14300  0.4080   9.34  1.326233
# D          0.004640  0.18900  0.9040   8.65  1.974021
# E          0.006850  0.30700  1.0130  19.90  3.682342
# F          0.201000  1.04000  3.9000  12.10  3.645836
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# categorias_dados['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# categorias_dados['50%'].plot(kind='hist', bins=20, title='50%')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# categorias_dados['75%'].plot(kind='hist', bins=20, title='75%')
# ...

# %% [markdown]
# #dois eixos juntos idade e peso, de lados opostos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_excel('/content/drive/MyDrive/georgia/ GEORGIA1.xlsx')
display(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#           DATA    G1 Protocol  Prontuário        Age Massa (kg) CATEGORIA  \
# 0   2023-07-07        CARDIAC    17170622   0.070000       3.24         A
# 1   2019-05-07         THORAX    15788953   0.083333       2.25         A
# 2   2021-03-28         THORAX    16336737   0.083333       5.74         A
# 3   2020-03-26  ORTHOPAEDICS     16088098   0.087600      3.545         A
# 4   2022-07-04         THORAX    16792020   0.098600       4.08         A
# ..         ...            ...         ...        ...        ...       ...
# 827 2018-06-15         THORAX    14302897  17.000000         78         E
# 828 2020-10-15         THORAX    16147548  18.000000       50.4         E
# 829 2020-01-07    VASCULAR HQ     9020157  18.000000       56.2         E
# 830 2019-06-11         THORAX     8684706  18.000000       69.2         E
# ...

# %%
categoria_cont = df['CATEGORIA'].value_counts()
categoria_cont = categoria_cont.reindex(['A', 'B', 'C', 'D', 'E', 'F'])
display(categoria_cont)

# Imprimindo as colunas do DataFrame para verificar o nome correto
print(df.columns)
# Out:
# CATEGORIA
# A    221.0
# B    379.0
# C    107.0
# D     87.0
# E     38.0
# F      NaN
# Name: count, dtype: float64
# Index(['DATA', 'G1 Protocol', 'Prontuário', 'Age', 'Massa (kg)', 'CATEGORIA',
#        'PKA DAP total (Gy.cm^2)'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Massa (kg)', y='PKA DAP total (Gy.cm^2)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5a5849d9c8a6> in <cell line: 2>()
#       1 from matplotlib import pyplot as plt
# ----> 2 df.plot(kind='scatter', x='Massa (kg)', y='PKA DAP total (Gy.cm^2)', s=32, alpha=.8)
#       3 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973         if kind in self._dataframe_kinds:
#     974             if isinstance(data, ABCDataFrame):
# --> 975                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976             else:
#     977                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...
